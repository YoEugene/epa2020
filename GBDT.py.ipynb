# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split, GridSearchCV

# Import relevant items
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import datetime as dt
from datetime import datetime
import math
# Import CSV file into a dataframe
df = pd.read_csv('./data/North/中山站/gbdt_2015_2018.csv')

# %%
df.head()
df['PM25_NOW'].describe()
# Out:
# count    34932.000000
# mean        17.459671
# std         11.954555
# min         -3.000000
# 25%          9.000000
# 50%         15.000000
# 75%         23.000000
# max        121.000000
# Name: PM25_NOW, dtype: float64

# %%
# df = df[[feat for feat in ['PM25_NOW','PM2.5_AVG12', 'DAY_OF_YEAR', 'PM2.5_AVG6', 'PM2.5_AVG3', 'PM2.5_AVG24', 'PM2.5_T1', 'HOUR', 'CH4_AVG3', 'PM10_AVG12',
# 'CH4_T1', 'RH_T1', 'CH4_AVG6', 'RH_T2', 'MONTH', 'PM2.5_T11', 'O3_AVG24', 'PM10_AVG24', 'CH4_AVG24', 'SO2_AVG24', 'PM10_T1', 'CH4_T4', 'RH_T3', 'PM2.5_T12', 'WIND_SPEED_T1', 'NO2_AVG24', 'WIND_SPEED_T2', 'AMB_TEMP_T2', 'SO2_AVG12', 'AMB_TEMP_T1', 'PM2.5_T10', 'AMB_TEMP_T3', 'NO2_AVG12', 'CO_T13', 'CO_AVG24', 'WS_HR_T1', 'PM10_AVG3',
#  'AMB_TEMP_T12', 'CH4_AVG12', 'CH4_T2', 'O3_T1', 'O3_AVG6', 'AMB_TEMP_T4', 'PM2.5_T36', 'PM2.5_T2', 'NMHC_AVG24', 'O3_AVG12', 'RH_T4', 'THC_T1', 'RH_T12', 'THC_AVG6', 'NO_AVG24', 'PM10_T36', 'O3_AVG3', 'SO2_T1',
#  'PM2.5_T3', 'RH_T5', 'RH_T10', 'THC_AVG3', 'WEEKDAY', 'PM2.5_T30', 'AMB_TEMP_T8',
#  'AMB_TEMP_T6', 'AMB_TEMP_T7', 'SO2_T13', 'NOx_AVG24', 'SO2_T35', 'NO2_AVG6', 'RH_T6', 'THC_AVG24', 'THC_AVG12',
#  'WD_HR_T1', 'O3_T13', 'RAINFALL_T1', 'NO_AVG12', 'NOx_AVG12', 'PM2.5_T9', 'CO_T15', 'AMB_TEMP_T11']]]

# df = df[[feat for feat in ['PM25_NOW','PM2.5_AVG12', 'DAY_OF_YEAR', 'PM2.5_AVG6', 'PM2.5_AVG3', 'PM2.5_AVG24', 'PM2.5_T1', 'HOUR', 'CH4_AVG3', 'PM10_AVG12',
# 'CH4_T1', 'RH_T1', 'CH4_AVG6', 'RH_T2', 'MONTH', 'PM2.5_T11', 'O3_AVG24', 'PM10_AVG24', 'CH4_AVG24', 'SO2_AVG24', 'PM10_T1', 'CH4_T4', 'RH_T3', 'PM2.5_T12', 'WIND_SPEED_T1', 'NO2_AVG24', 'WIND_SPEED_T2', 'AMB_TEMP_T2', 'SO2_AVG12', 'AMB_TEMP_T1', 'PM2.5_T10', 'AMB_TEMP_T3', 'NO2_AVG12', 'CO_T13', 'RH_T24', 'CO_AVG24', 'AMB_TEMP_T13', 'WS_HR_T1', 'PM10_AVG3',
#  'AMB_TEMP_T24', 'AMB_TEMP_T12', 'CH4_AVG12', 'CH4_T2', 'O3_T1', 'O3_AVG6', 'AMB_TEMP_T4', 'PM2.5_T36', 'PM2.5_T2', 'NMHC_AVG24', 'O3_AVG12', 'PM2.5_T61', 'RH_T4', 'THC_T1', 'RH_T12', 'THC_AVG6', 'NO_AVG24', 'PM10_T36', 'O3_AVG3', 'SO2_T1',
#  'PM2.5_T3', 'RH_T5', 'RH_T10', 'THC_AVG3', 'RH_T15', 'AMB_TEMP_T15', 'WEEKDAY', 'PM2.5_T30', 'PM10_T70', 'AMB_TEMP_T8',
#  'AMB_TEMP_T22', 'AMB_TEMP_T6', 'AMB_TEMP_T17', 'PM2.5_T37', 'PM10_T71', 'AMB_TEMP_T7', 'SO2_T13', 'SO2_T37', 'NOx_AVG24', 'PM10_T72', 'SO2_T35', 'AMB_TEMP_T14', 'NO2_AVG6', 'RH_T6', 'RH_T21', 'THC_AVG24', 'PM10_T37', 'THC_AVG12', 'RH_T23',
#  'WD_HR_T1', 'O3_T13', 'PM10_T52', 'RAINFALL_T1', 'NO_AVG12', 'PM2.5_T38', 'NOx_AVG12', 'PM2.5_T9', 'CO_T15', 'PM10_T55'
# , 'SO2_T59', 'AMB_TEMP_T11', 'CO_T38'] if 'AVG' not in feat]]

# %%
df.drop(['PM25_NOW'], axis=1)
# Out:
#        PM2.5_T1  PM2.5_T2  PM2.5_T3  PM2.5_T4  PM2.5_T5  PM2.5_T6  PM2.5_T7  \
# 0          17.0      15.0      21.0      17.0      15.0      14.0      14.0
# 1          15.0      17.0      15.0      21.0      17.0      15.0      14.0
# 2          16.0      15.0      17.0      15.0      21.0      17.0      15.0
# 3           3.0      16.0      15.0      17.0      15.0      21.0      17.0
# 4           4.0       3.0      16.0      15.0      17.0      15.0      21.0
# ...         ...       ...       ...       ...       ...       ...       ...
# 34927       3.0       6.0       7.0      14.0       7.0      13.0       6.0
# 34928       5.0       3.0       6.0       7.0      14.0       7.0      13.0
# 34929       7.0       5.0       3.0       6.0       7.0      14.0       7.0
# 34930       7.0       7.0       5.0       3.0       6.0       7.0      14.0
# 34931       1.0       7.0       7.0       5.0       3.0       6.0       7.0
#
#        PM2.5_T8  PM2.5_T9  PM2.5_T10  ...  THC_DIVTSQR_T7  THC_DIVTSQR_T8  \
# 0          12.0       9.0       10.0  ...        0.042857        0.031250
# 1          14.0      12.0        9.0  ...        0.046939        0.032813
# 2          14.0      14.0       12.0  ...        0.046939        0.035937
# 3          15.0      14.0       14.0  ...        0.046939        0.035937
# 4          17.0      15.0       14.0  ...        0.048980        0.035937
# ...         ...       ...        ...  ...             ...             ...
# 34927      10.0       6.0        5.0  ...        0.038776        0.029687
# 34928       6.0      10.0        6.0  ...        0.038776        0.029687
# 34929      13.0       6.0       10.0  ...        0.038776        0.029687
# 34930       7.0      13.0        6.0  ...        0.038776        0.029687
# 34931      14.0       7.0       13.0  ...        0.038776        0.029687
#
#        THC_DIVTSQR_T9  THC_DIVTSQR_T10  THC_DIVTSQR_T11  THC_DIVTSQR_T12  \
# 0            0.024691            0.020         0.015702         0.013194
# 1            0.024691            0.020         0.016529         0.013194
# 2            0.025926            0.020         0.016529         0.013889
# 3            0.028395            0.021         0.016529         0.013889
# 4            0.028395            0.023         0.017355         0.013889
# ...               ...              ...              ...              ...
# 34927        0.023457            0.019         0.015702         0.013194
# 34928        0.023457            0.019         0.015702         0.013194
# 34929        0.023457            0.019         0.015702         0.013194
# 34930        0.023457            0.019         0.015702         0.013194
# 34931        0.023457            0.019         0.015702         0.013194
#
#        DAY_OF_YEAR  HOUR  WEEKDAY  MONTH
# 0                3    13        6      1
# 1                3    14        6      1
# 2                3    15        6      1
# 3                3    16        6      1
# 4                3    17        6      1
# ...            ...   ...      ...    ...
# 34927          364    20        0     12
# 34928          364    21        0     12
# 34929          364    22        0     12
# 34930          364    23        0     12
# 34931          364    24        0     12
#
# [34932 rows x 660 columns]

# %%
X_train, y_train = df.drop(['PM25_NOW'], axis=1), df['PM25_NOW']

# %%
df_test = pd.read_csv('./data/North/中山站/gbdt_2019.csv')
df_test['PM25_NOW'].describe()
# Out:
# count    8676.000000
# mean       14.478261
# std         9.130924
# min         1.000000
# 25%         8.000000
# 50%        13.000000
# 75%        19.000000
# max        83.000000
# Name: PM25_NOW, dtype: float64

# %%
# df_test = df_test[[feat for feat in ['PM25_NOW','PM2.5_AVG12', 'DAY_OF_YEAR', 'PM2.5_AVG6', 'PM2.5_AVG3', 'PM2.5_AVG24', 'PM2.5_T1', 'HOUR', 'CH4_AVG3', 'PM10_AVG12',
# 'CH4_T1', 'RH_T1', 'CH4_AVG6', 'RH_T2', 'MONTH', 'PM2.5_T11', 'O3_AVG24', 'PM10_AVG24', 'CH4_AVG24', 'SO2_AVG24', 'PM10_T1', 'CH4_T4', 'RH_T3', 'PM2.5_T12', 'WIND_SPEED_T1', 'NO2_AVG24', 'WIND_SPEED_T2', 'AMB_TEMP_T2', 'SO2_AVG12', 'AMB_TEMP_T1', 'PM2.5_T10', 'AMB_TEMP_T3', 'NO2_AVG12', 'CO_T13', 'CO_AVG24', 'WS_HR_T1', 'PM10_AVG3',
#  'AMB_TEMP_T12', 'CH4_AVG12', 'CH4_T2', 'O3_T1', 'O3_AVG6', 'AMB_TEMP_T4', 'PM2.5_T36', 'PM2.5_T2', 'NMHC_AVG24', 'O3_AVG12', 'RH_T4', 'THC_T1', 'RH_T12', 'THC_AVG6', 'NO_AVG24', 'PM10_T36', 'O3_AVG3', 'SO2_T1',
#  'PM2.5_T3', 'RH_T5', 'RH_T10', 'THC_AVG3', 'WEEKDAY', 'PM2.5_T30', 'AMB_TEMP_T8',
#  'AMB_TEMP_T6', 'AMB_TEMP_T7', 'SO2_T13', 'NOx_AVG24', 'SO2_T35', 'NO2_AVG6', 'RH_T6', 'THC_AVG24', 'THC_AVG12',
#  'WD_HR_T1', 'O3_T13', 'RAINFALL_T1', 'NO_AVG12', 'NOx_AVG12', 'PM2.5_T9', 'CO_T15', 'AMB_TEMP_T11']]]

X_test, y_test = df_test.drop(['PM25_NOW'], axis=1), df_test['PM25_NOW']

# %%
# parameters = {'learning_rate': [0.1], 'n_estimators': [256], 'max_depth': [6,8,10], 'max_features': [0.2,0.4], 'verbose': [1], 'random_state': [0]}

# gbr = GradientBoostingRegressor()

# model = GridSearchCV(gbr, parameters)

# %%
# model.fit(X_train, y_train)

# %%
# model.cv_results_

# %%
# reg = GradientBoostingRegressor(learning_rate=0.1, n_estimators=256, max_depth=10, verbose=1, max_features=0.2, random_state=0)
reg = GradientBoostingRegressor(learning_rate=0.1, n_estimators=128, verbose=1, random_state=42)
# reg = GradientBoostingRegressor(verbose=1, random_state=42)

reg.fit(X_train, y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1         136.7916            2.01m
#          2         131.7710            2.07m
#          3         127.4578            2.15m
#          4         123.7943            2.09m
#          5         120.6578            2.08m
#          6         117.9592            2.07m
#          7         115.4132            2.03m
#          8         113.2624            2.01m
#          9         111.1936            1.99m
#         10         109.5263            1.95m
#         20          98.9375            1.75m
#         30          93.8718            1.57m
#         40          90.7572            1.37m
#         50          88.3687            1.20m
#         60          86.7802            1.01m
#         70          85.2249           50.33s
#         80          83.9832           40.84s
#         90          82.3951           31.78s
#        100          81.3840           23.14s
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=128,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=1, warm_start=False)

# %%
import pandas as pd
# %matplotlib inline
#do code to support model
#"data" is the X dataframe and model is the SKlearn object

feats = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(df.drop(['PM25_NOW'], axis=1).columns, reg.feature_importances_):
    feats[feature] = importance #add the name/value pair 

{k: v for k, v in sorted(feats.items(), key=lambda item: item[1], reverse=True)}
# importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-importance'})
# importances.sort_values(by='Gini-importance').plot(kind='bar', rot=45)
# Out:
# {'PM2.5_AVG12': 0.27851707525744535,
#  'PM2.5_T1': 0.10854298847214311,
#  'DAY_OF_YEAR': 0.07530052136069544,
#  'HOUR': 0.06825115623855688,
#  'RH_T1': 0.03902610682719987,
#  'CH4_T1': 0.03413227420845767,
#  'PM2.5_AVG72': 0.024849108536690347,
#  'CH4_AVG3': 0.022785883285731546,
#  'NO2_AVG72': 0.017613490644952188,
#  'PM2.5_AVG24': 0.015365996188410743,
#  'MONTH': 0.015087090617947276,
#  'WIND_SPEED_T1': 0.012798945740145243,
#  'O3_AVG24': 0.012268703091975823,
#  'WS_HR_T1': 0.008852891691382555,
#  'CH4_DIVTSQR_T2': 0.008283407828939878,
#  'SO2_AVG72': 0.007927413873010356,
#  'PM10_AVG24': 0.006907466777277314,
#  'NO2_T36': 0.006693845243877978,
#  'PM10_AVG72': 0.006509137942764346,
#  'RH_T2': 0.0059250081804004704,
#  'SO2_AVG24': 0.005905723351694107,
#  'CH4_AVG72': 0.005712706079907024,
#  'CH4_AVG24': 0.005683313297751284,
#  'SO2_AVG12': 0.005345460928971913,
#  'NO_AVG24': 0.005331811541698171,
#  'NMHC_AVG24': 0.004745899906138164,
#  'CO_AVG24': 0.004695912209787693,
#  'AMB_TEMP_T1': 0.0038457744126536675,
#  'O3_T1': 0.0036902361850734756,
#  'THC_AVG6': 0.0036670795356074258,
#  'PM10_T36': 0.0036473998736850787,
#  'NO_AVG72': 0.0036154371480798444,
#  'WIND_SPEED_T3': 0.003587974959154761,
#  'O3_T13': 0.0035771288267003563,
#  'THC_T1': 0.0033557855421724103,
#  'AMB_TEMP_T6': 0.003014809201125139,
#  'RH_T10': 0.0029862863045622247,
#  'RH_T3': 0.0028067094566285177,
#  'THC_AVG72': 0.002751419880793331,
#  'CO_T13': 0.002604959252723444,
#  'PM10_AVG12': 0.0025437869096885247,
#  'CH4_AVG6': 0.002538620809739719,
#  'AMB_TEMP_T12': 0.002510925764797529,
#  'RH_T9': 0.0023838699161587438,
#  'RAINFALL_T1': 0.002382264379524133,
#  'NOx_AVG72': 0.002331072097446774,
#  'PM2.5_T35': 0.0023260359008247717,
#  'WS_HR_T11': 0.002322240126912711,
#  'PM2.5_AVG3': 0.002284123542230863,
#  'O3_T14': 0.0022561946088492622,
#  'NO2_T13': 0.002224299327525627,
#  'SO2_T35': 0.0021394456522947298,
#  'PM2.5_AVG6': 0.00206696138112721,
#  'PM2.5_T32': 0.002042729457680724,
#  'AMB_TEMP_T5': 0.002007314929914036,
#  'SO2_T34': 0.0019257872638544014,
#  'CO_T14': 0.0018837665954306668,
#  'CO_AVG12': 0.0018655771843028792,
#  'CO_AVG6': 0.0018464346098340384,
#  'PM10_AVG6': 0.0018200692246947633,
#  'PM10_T1': 0.0016864911930796142,
#  'AMB_TEMP_T4': 0.001685105747344909,
#  'CH4_AVG12': 0.0015822403690988502,
#  'WIND_SPEED_T2': 0.0015365132252661414,
#  'WIND_SPEED_T4': 0.0015341334306655096,
#  'NO_T22': 0.0015271100596177384,
#  'O3_T12': 0.001522197218549424,
#  'CO_T15': 0.0014880774093533442,
#  'PM10_DIVTSQR_T9': 0.0014871477170662185,
#  'WS_HR_T5': 0.0014385881666379142,
#  'WD_HR_T4': 0.0013650307942750255,
#  'PM2.5_T25': 0.0013068879943522603,
#  'WEEKDAY': 0.0012976460850791642,
#  'AMB_TEMP_T2': 0.0012662641918670086,
#  'O3_T21': 0.001252108503310907,
#  'NO2_AVG24': 0.0012481632502476703,
#  'NO_T20': 0.0012254462552067449,
#  'RH_T4': 0.0012173249318345116,
#  'PM10_T23': 0.0012110635191496671,
#  'PM2.5_T13': 0.0011900122783506174,
#  'NO2_T1': 0.001172825227877506,
#  'NO_AVG12': 0.0011607811021509833,
#  'THC_AVG3': 0.001142719600594754,
#  'THC_AVG24': 0.0011320255041208545,
#  'PM2.5_DIVTSQR_T7': 0.0011279074499545316,
#  'PM2.5_T26': 0.00110489225662174,
#  'NMHC_AVG72': 0.0010908724411220485,
#  'AMB_TEMP_T3': 0.0010553270022632508,
#  'NO_DIVTSQR_T12': 0.0010409949757513883,
#  'WD_HR_T1': 0.001033595926487437,
#  'NMHC_T1': 0.0010100210848409733,
#  'WS_HR_T12': 0.0009743421910102313,
#  'SO2_DIVTSQR_T11': 0.0009667385943576015,
#  'PM10_DIVTSQR_T8': 0.0009595841337541642,
#  'WS_HR_T10': 0.0009394470141139226,
#  'AMB_TEMP_T11': 0.000935958637097273,
#  'SO2_DIVTSQR_T12': 0.0009296208584418043,
#  'O3_DIVTSQR_T12': 0.0009049777983830975,
#  'O3_AVG72': 0.0008907407104044353,
#  'NOx_AVG24': 0.0008857186519047042,
#  'NO2_AVG12': 0.0008716338985812481,
#  'O3_DIVTSQR_T11': 0.0007978115026231969,
#  'SO2_T36': 0.0007549034295458054,
#  'CO_AVG72': 0.0007131698857805235,
#  'PM2.5_T23': 0.0007117935353814355,
#  'CO_T1': 0.0007101236243948652,
#  'PM10_T34': 0.0006873360493661246,
#  'AMB_TEMP_T7': 0.0006656143325310053,
#  'NO_T23': 0.0006532160915118287,
#  'O3_T27': 0.0006368515652893629,
#  'PM10_T6': 0.0006221567616260113,
#  'PM10_T35': 0.0006152016905442052,
#  'WD_HR_T5': 0.000600490896958767,
#  'WD_HR_T3': 0.0005932906747983102,
#  'AMB_TEMP_T8': 0.0005814924521121442,
#  'O3_AVG12': 0.0005785700959048501,
#  'WD_HR_T6': 0.00057233022878973,
#  'CO_T26': 0.000569918636140055,
#  'CO_T17': 0.000568366961097144,
#  'PM10_AVG3': 0.0005484143879019543,
#  'SO2_DIVTSQR_T9': 0.0005478485256400694,
#  'PM2.5_T5': 0.0005356010280708242,
#  'NO2_T12': 0.0005329783541203347,
#  'WIND_SPEED_T5': 0.0005277859934760753,
#  'O3_AVG3': 0.0005270912128520556,
#  'PM2.5_T30': 0.0005267963944437044,
#  'SO2_T30': 0.0005208196735691784,
#  'CO_T11': 0.0005170985715265,
#  'PM10_T32': 0.0005167197584164282,
#  'CH4_T25': 0.0005129389144737451,
#  'THC_AVG12': 0.0005038988210324105,
#  'NO_T27': 0.0005037027697952708,
#  'NO_AVG6': 0.0004972378883181874,
#  'NO_T1': 0.0004946979225445717,
#  'PM10_T22': 0.000489205370635998,
#  'SO2_T24': 0.00047977269562941713,
#  'NO_DIVTSQR_T3': 0.0004770821970496619,
#  'NOx_AVG12': 0.00047672903911890696,
#  'O3_T11': 0.0004755848504720217,
#  'CO_DIVTSQR_T2': 0.00046952582164141196,
#  'WD_HR_T10': 0.0004665911616305077,
#  'THC_T23': 0.0004655337567555197,
#  'NMHC_AVG3': 0.0004548789598377485,
#  'AMB_TEMP_T9': 0.00044513440114206447,
#  'O3_DIVTSQR_T7': 0.0004300533147725964,
#  'CO_T31': 0.00042644974032696534,
#  'NO2_T33': 0.0004245598567048477,
#  'O3_T31': 0.0004069778974029227,
#  'PM2.5_T18': 0.0004037827664647586,
#  'PM10_T24': 0.0004001240395898055,
#  'CO_T16': 0.00039714099165099714,
#  'O3_T15': 0.00039150820530771575,
#  'SO2_T33': 0.0003912787235617899,
#  'SO2_T23': 0.000380981124704036,
#  'NO_T3': 0.0003796717976310353,
#  'PM2.5_T3': 0.00037446573107256326,
#  'PM10_T14': 0.0003681684507647252,
#  'PM2.5_DIVTSQR_T8': 0.00036052653372090364,
#  'SO2_T32': 0.00035627189850979913,
#  'WD_HR_T8': 0.00035526284592211574,
#  'PM10_T3': 0.0003493240122452419,
#  'O3_T6': 0.00034780336555830595,
#  'O3_T19': 0.00034492030001457755,
#  'O3_DIVTSQR_T4': 0.00033919283209698104,
#  'PM10_DIVTSQR_T7': 0.000336874121265004,
#  'SO2_T25': 0.0003348241302817838,
#  'PM2.5_T14': 0.0003337999610241639,
#  'WIND_DIREC_T1': 0.00033303098471008973,
#  'CH4_T2': 0.00032801911627238997,
#  'O3_T16': 0.00032564067082922554,
#  'PM2.5_DIVTSQR_T6': 0.00032336725076080564,
#  'PM2.5_T2': 0.0003191258165442554,
#  'CO_T19': 0.0003144531522067674,
#  'RH_T5': 0.000304786773074321,
#  'O3_T28': 0.00030256898780643324,
#  'PM10_T15': 0.0003003385776910124,
#  'O3_T22': 0.0002914488149619758,
#  'SO2_DIVTSQR_T5': 0.00028833687847634824,
#  'PM2.5_T33': 0.000286099993978314,
#  'PM10_T8': 0.00028316141078773064,
#  'NO2_DIVTSQR_T7': 0.00027983993034135516,
#  'CO_T12': 0.00027839976230108876,
#  'WS_HR_T4': 0.0002741880332052932,
#  'NOx_T5': 0.00026648475539708076,
#  'O3_AVG6': 0.00026329931945657755,
#  'SO2_T20': 0.0002591657737516818,
#  'NO_DIVTSQR_T9': 0.0002584071641628942,
#  'NO_DIVTSQR_T2': 0.00025618871263659673,
#  'NO_T15': 0.0002431201309323572,
#  'CH4_T17': 0.00024046824360173086,
#  'PM2.5_T29': 0.00023837573363240955,
#  'PM2.5_T8': 0.00023612260852018532,
#  'CO_DIVTSQR_T12': 0.0002270294259768582,
#  'WS_HR_T8': 0.00022627950344499112,
#  'PM10_T4': 0.00022617590954385162,
#  'NMHC_T23': 0.00022423894859384272,
#  'O3_T29': 0.00022370864579582885,
#  'PM10_DIVTSQR_T12': 0.00021694857619159374,
#  'CO_DIVTSQR_T5': 0.00021654205701698633,
#  'WD_HR_T11': 0.0002162514140914243,
#  'CO_T34': 0.0002156661202322643,
#  'NMHC_DIVTSQR_T3': 0.00021393378970603505,
#  'O3_T36': 0.00020961529425641594,
#  'NOx_T29': 0.00020749624815105474,
#  'RAINFALL_T5': 0.00020615072530078771,
#  'NO_T19': 0.00020442613867610335,
#  'SO2_AVG6': 0.00020301914586945625,
#  'PM10_DIVTSQR_T4': 0.0002000210052372573,
#  'NMHC_AVG12': 0.0001946085637241982,
#  'PM2.5_T15': 0.0001941770268131845,
#  'NO2_AVG6': 0.00019347762542301652,
#  'O3_T23': 0.00019118788062145564,
#  'PM10_DIVTSQR_T3': 0.0001876597973367487,
#  'SO2_T17': 0.00018618389348385404,
#  'CH4_T15': 0.00017633207373852618,
#  'NO2_T25': 0.0001750406567294553,
#  'NO_T16': 0.0001706431291230731,
#  'SO2_T21': 0.00016547564974096372,
#  'PM10_DIVTSQR_T2': 0.0001616421617855453,
#  'NOx_T31': 0.0001587497387510087,
#  'O3_T18': 0.00015481866544936419,
#  'SO2_AVG3': 0.00015384191461174338,
#  'RH_T7': 0.00015310431263386884,
#  'NO_AVG3': 0.000152045252320317,
#  'CH4_T20': 0.0001508906470466724,
#  'SO2_T19': 0.00014701711986315601,
#  'O3_DIVTSQR_T8': 0.00014547997351238315,
#  'PM10_T31': 0.00014534486789535592,
#  'NO2_T14': 0.0001447917748533957,
#  'NMHC_DIVTSQR_T4': 0.0001380504616302709,
#  'SO2_DIVTSQR_T8': 0.00013691224340185614,
#  'PM10_T7': 0.00013611203937573927,
#  'PM2.5_T16': 0.00013472707954948935,
#  'NO_T29': 0.00013409029784251087,
#  'SO2_T6': 0.00013382281871282233,
#  'NO2_T28': 0.00013313405736984206,
#  'SO2_T22': 0.0001327668108326822,
#  'PM10_T2': 0.000128276840931512,
#  'THC_T30': 0.00012782323678940343,
#  'PM10_T33': 0.0001253359529269012,
#  'O3_T3': 0.00012238333224439454,
#  'NO_T14': 0.00012210455572082672,
#  'PM2.5_T24': 0.00012135685187820984,
#  'CO_T5': 0.00011286872692295964,
#  'SO2_T27': 0.00011253635221004549,
#  'PM10_T17': 0.0001109286034417068,
#  'SO2_T8': 0.00011070789901620124,
#  'NMHC_T21': 0.00011038313751908216,
#  'NMHC_T4': 0.00010278166650759477,
#  'NOx_T9': 9.719958301793215e-05,
#  'NO_T5': 9.305821587262886e-05,
#  'SO2_T26': 9.080287950267967e-05,
#  'RAINFALL_T8': 9.019400679086772e-05,
#  'SO2_DIVTSQR_T10': 8.692275462246043e-05,
#  'O3_T26': 8.218889012854885e-05,
#  'NMHC_T31': 7.236464945242108e-05,
#  'NO_T24': 6.69602649544923e-05,
#  'NOx_T25': 6.077833163728802e-05,
#  'NO_DIVTSQR_T10': 6.074994987758607e-05,
#  'NMHC_T36': 5.927968117054263e-05,
#  'NO2_T18': 5.5199780541595514e-05,
#  'SO2_T12': 5.3512403715405546e-05,
#  'NO_T11': 5.0627220546687e-05,
#  'O3_DIVTSQR_T9': 4.953123733319783e-05,
#  'PM2.5_T17': 4.388342202817659e-05,
#  'THC_T24': 4.3211473231755225e-05,
#  'PM10_T29': 4.2216935203789223e-05,
#  'SO2_T1': 3.987528135174052e-05,
#  'NOx_AVG6': 3.266775290318624e-05,
#  'O3_T24': 3.2115134024497805e-05,
#  'SO2_T4': 2.248384768807619e-05,
#  'NO_T32': 1.594870618823739e-05,
#  'NOx_DIVTSQR_T8': 1.3567137074731752e-05,
#  'CO_T33': 1.251581647140496e-05,
#  'NMHC_T34': 1.1973250083466345e-05,
#  'NMHC_T2': 4.522982812168096e-06,
#  'SO2_T29': 2.018130038159575e-06,
#  'THC_T7': 1.1419698457027886e-06,
#  'PM2.5_T31': 2.6963281914175866e-07,
#  'NMHC_AVG6': 2.5171916886557474e-07,
#  'NMHC_T7': 3.2144822180067245e-09,
#  'PM2.5_T4': 0.0,
#  'PM2.5_T6': 0.0,
#  'PM2.5_T7': 0.0,
#  'PM2.5_T9': 0.0,
#  'PM2.5_T10': 0.0,
#  'PM2.5_T11': 0.0,
#  'PM2.5_T12': 0.0,
#  'PM2.5_T19': 0.0,
#  'PM2.5_T20': 0.0,
#  'PM2.5_T21': 0.0,
#  'PM2.5_T22': 0.0,
#  'PM2.5_T27': 0.0,
#  'PM2.5_T28': 0.0,
#  'PM2.5_T34': 0.0,
#  'PM2.5_T36': 0.0,
#  'O3_T2': 0.0,
#  'O3_T4': 0.0,
#  'O3_T5': 0.0,
#  'O3_T7': 0.0,
#  'O3_T8': 0.0,
#  'O3_T9': 0.0,
#  'O3_T10': 0.0,
#  'O3_T17': 0.0,
#  'O3_T20': 0.0,
#  'O3_T25': 0.0,
#  'O3_T30': 0.0,
#  'O3_T32': 0.0,
#  'O3_T33': 0.0,
#  'O3_T34': 0.0,
#  'O3_T35': 0.0,
#  'CH4_T3': 0.0,
#  'CH4_T4': 0.0,
#  'CH4_T5': 0.0,
#  'CH4_T6': 0.0,
#  'CH4_T7': 0.0,
#  'CH4_T8': 0.0,
#  'CH4_T9': 0.0,
#  'CH4_T10': 0.0,
#  'CH4_T11': 0.0,
#  'CH4_T12': 0.0,
#  'CH4_T13': 0.0,
#  'CH4_T14': 0.0,
#  'CH4_T16': 0.0,
#  'CH4_T18': 0.0,
#  'CH4_T19': 0.0,
#  'CH4_T21': 0.0,
#  'CH4_T22': 0.0,
#  'CH4_T23': 0.0,
#  'CH4_T24': 0.0,
#  'CH4_T26': 0.0,
#  'CH4_T27': 0.0,
#  'CH4_T28': 0.0,
#  'CH4_T29': 0.0,
#  'CH4_T30': 0.0,
#  'CH4_T31': 0.0,
#  'CH4_T32': 0.0,
#  'CH4_T33': 0.0,
#  'CH4_T34': 0.0,
#  'CH4_T35': 0.0,
#  'CH4_T36': 0.0,
#  'CO_T2': 0.0,
#  'CO_T3': 0.0,
#  'CO_T4': 0.0,
#  'CO_T6': 0.0,
#  'CO_T7': 0.0,
#  'CO_T8': 0.0,
#  'CO_T9': 0.0,
#  'CO_T10': 0.0,
#  'CO_T18': 0.0,
#  'CO_T20': 0.0,
#  'CO_T21': 0.0,
#  'CO_T22': 0.0,
#  'CO_T23': 0.0,
#  'CO_T24': 0.0,
#  'CO_T25': 0.0,
#  'CO_T27': 0.0,
#  'CO_T28': 0.0,
#  'CO_T29': 0.0,
#  'CO_T30': 0.0,
#  'CO_T32': 0.0,
#  'CO_T35': 0.0,
#  'CO_T36': 0.0,
#  'NMHC_T3': 0.0,
#  'NMHC_T5': 0.0,
#  'NMHC_T6': 0.0,
#  'NMHC_T8': 0.0,
#  'NMHC_T9': 0.0,
#  'NMHC_T10': 0.0,
#  'NMHC_T11': 0.0,
#  'NMHC_T12': 0.0,
#  'NMHC_T13': 0.0,
#  'NMHC_T14': 0.0,
#  'NMHC_T15': 0.0,
#  'NMHC_T16': 0.0,
#  'NMHC_T17': 0.0,
#  'NMHC_T18': 0.0,
#  'NMHC_T19': 0.0,
#  'NMHC_T20': 0.0,
#  'NMHC_T22': 0.0,
#  'NMHC_T24': 0.0,
#  'NMHC_T25': 0.0,
#  'NMHC_T26': 0.0,
#  'NMHC_T27': 0.0,
#  'NMHC_T28': 0.0,
#  'NMHC_T29': 0.0,
#  'NMHC_T30': 0.0,
#  'NMHC_T32': 0.0,
#  'NMHC_T33': 0.0,
#  'NMHC_T35': 0.0,
#  'NO_T2': 0.0,
#  'NO_T4': 0.0,
#  'NO_T6': 0.0,
#  'NO_T7': 0.0,
#  'NO_T8': 0.0,
#  'NO_T9': 0.0,
#  'NO_T10': 0.0,
#  'NO_T12': 0.0,
#  'NO_T13': 0.0,
#  'NO_T17': 0.0,
#  'NO_T18': 0.0,
#  'NO_T21': 0.0,
#  'NO_T25': 0.0,
#  'NO_T26': 0.0,
#  'NO_T28': 0.0,
#  'NO_T30': 0.0,
#  'NO_T31': 0.0,
#  'NO_T33': 0.0,
#  'NO_T34': 0.0,
#  'NO_T35': 0.0,
#  'NO_T36': 0.0,
#  'NO2_T2': 0.0,
#  'NO2_T3': 0.0,
#  'NO2_T4': 0.0,
#  'NO2_T5': 0.0,
#  'NO2_T6': 0.0,
#  'NO2_T7': 0.0,
#  'NO2_T8': 0.0,
#  'NO2_T9': 0.0,
#  'NO2_T10': 0.0,
#  'NO2_T11': 0.0,
#  'NO2_T15': 0.0,
#  'NO2_T16': 0.0,
#  'NO2_T17': 0.0,
#  'NO2_T19': 0.0,
#  'NO2_T20': 0.0,
#  'NO2_T21': 0.0,
#  'NO2_T22': 0.0,
#  'NO2_T23': 0.0,
#  'NO2_T24': 0.0,
#  'NO2_T26': 0.0,
#  'NO2_T27': 0.0,
#  'NO2_T29': 0.0,
#  'NO2_T30': 0.0,
#  'NO2_T31': 0.0,
#  'NO2_T32': 0.0,
#  'NO2_T34': 0.0,
#  'NO2_T35': 0.0,
#  'NOx_T1': 0.0,
#  'NOx_T2': 0.0,
#  'NOx_T3': 0.0,
#  'NOx_T4': 0.0,
#  'NOx_T6': 0.0,
#  'NOx_T7': 0.0,
#  'NOx_T8': 0.0,
#  'NOx_T10': 0.0,
#  'NOx_T11': 0.0,
#  'NOx_T12': 0.0,
#  'NOx_T13': 0.0,
#  'NOx_T14': 0.0,
#  'NOx_T15': 0.0,
#  'NOx_T16': 0.0,
#  'NOx_T17': 0.0,
#  'NOx_T18': 0.0,
#  'NOx_T19': 0.0,
#  'NOx_T20': 0.0,
#  'NOx_T21': 0.0,
#  'NOx_T22': 0.0,
#  'NOx_T23': 0.0,
#  'NOx_T24': 0.0,
#  'NOx_T26': 0.0,
#  'NOx_T27': 0.0,
#  'NOx_T28': 0.0,
#  'NOx_T30': 0.0,
#  'NOx_T32': 0.0,
#  'NOx_T33': 0.0,
#  'NOx_T34': 0.0,
#  'NOx_T35': 0.0,
#  'NOx_T36': 0.0,
#  'PM10_T5': 0.0,
#  'PM10_T9': 0.0,
#  'PM10_T10': 0.0,
#  'PM10_T11': 0.0,
#  'PM10_T12': 0.0,
#  'PM10_T13': 0.0,
#  'PM10_T16': 0.0,
#  'PM10_T18': 0.0,
#  'PM10_T19': 0.0,
#  'PM10_T20': 0.0,
#  'PM10_T21': 0.0,
#  'PM10_T25': 0.0,
#  'PM10_T26': 0.0,
#  'PM10_T27': 0.0,
#  'PM10_T28': 0.0,
#  'PM10_T30': 0.0,
#  'SO2_T2': 0.0,
#  'SO2_T3': 0.0,
#  'SO2_T5': 0.0,
#  'SO2_T7': 0.0,
#  'SO2_T9': 0.0,
#  'SO2_T10': 0.0,
#  'SO2_T11': 0.0,
#  'SO2_T13': 0.0,
#  'SO2_T14': 0.0,
#  'SO2_T15': 0.0,
#  'SO2_T16': 0.0,
#  'SO2_T18': 0.0,
#  'SO2_T28': 0.0,
#  'SO2_T31': 0.0,
#  'THC_T2': 0.0,
#  'THC_T3': 0.0,
#  'THC_T4': 0.0,
#  'THC_T5': 0.0,
#  'THC_T6': 0.0,
#  'THC_T8': 0.0,
#  'THC_T9': 0.0,
#  'THC_T10': 0.0,
#  'THC_T11': 0.0,
#  'THC_T12': 0.0,
#  'THC_T13': 0.0,
#  'THC_T14': 0.0,
#  'THC_T15': 0.0,
#  'THC_T16': 0.0,
#  'THC_T17': 0.0,
#  'THC_T18': 0.0,
#  'THC_T19': 0.0,
#  'THC_T20': 0.0,
#  'THC_T21': 0.0,
#  'THC_T22': 0.0,
#  'THC_T25': 0.0,
#  'THC_T26': 0.0,
#  'THC_T27': 0.0,
#  'THC_T28': 0.0,
#  'THC_T29': 0.0,
#  'THC_T31': 0.0,
#  'THC_T32': 0.0,
#  'THC_T33': 0.0,
#  'THC_T34': 0.0,
#  'THC_T35': 0.0,
#  'THC_T36': 0.0,
#  'AMB_TEMP_T10': 0.0,
#  'RAINFALL_T2': 0.0,
#  'RAINFALL_T3': 0.0,
#  'RAINFALL_T4': 0.0,
#  'RAINFALL_T6': 0.0,
#  'RAINFALL_T7': 0.0,
#  'RAINFALL_T9': 0.0,
#  'RAINFALL_T10': 0.0,
#  'RAINFALL_T11': 0.0,
#  'RAINFALL_T12': 0.0,
#  'RH_T6': 0.0,
#  'RH_T8': 0.0,
#  'RH_T11': 0.0,
#  'RH_T12': 0.0,
#  'WD_HR_T2': 0.0,
#  'WD_HR_T7': 0.0,
#  'WD_HR_T9': 0.0,
#  'WD_HR_T12': 0.0,
#  'WIND_DIREC_T2': 0.0,
#  'WIND_DIREC_T3': 0.0,
#  'WIND_DIREC_T4': 0.0,
#  'WIND_DIREC_T5': 0.0,
#  'WIND_DIREC_T6': 0.0,
#  'WIND_DIREC_T7': 0.0,
#  'WIND_DIREC_T8': 0.0,
#  'WIND_DIREC_T9': 0.0,
#  'WIND_DIREC_T10': 0.0,
#  'WIND_DIREC_T11': 0.0,
#  'WIND_DIREC_T12': 0.0,
#  'WIND_SPEED_T6': 0.0,
#  'WIND_SPEED_T7': 0.0,
#  'WIND_SPEED_T8': 0.0,
#  'WIND_SPEED_T9': 0.0,
#  'WIND_SPEED_T10': 0.0,
#  'WIND_SPEED_T11': 0.0,
#  'WIND_SPEED_T12': 0.0,
#  'WS_HR_T2': 0.0,
#  'WS_HR_T3': 0.0,
#  'WS_HR_T6': 0.0,
#  'WS_HR_T7': 0.0,
#  'WS_HR_T9': 0.0,
#  'CO_AVG3': 0.0,
#  'NO2_AVG3': 0.0,
#  'NOx_AVG3': 0.0,
#  'PM2.5_DIVTSQR_T2': 0.0,
#  'PM2.5_DIVTSQR_T3': 0.0,
#  'PM2.5_DIVTSQR_T4': 0.0,
#  'PM2.5_DIVTSQR_T5': 0.0,
#  'PM2.5_DIVTSQR_T9': 0.0,
#  'PM2.5_DIVTSQR_T10': 0.0,
#  'PM2.5_DIVTSQR_T11': 0.0,
#  'PM2.5_DIVTSQR_T12': 0.0,
#  'O3_DIVTSQR_T2': 0.0,
#  'O3_DIVTSQR_T3': 0.0,
#  'O3_DIVTSQR_T5': 0.0,
#  'O3_DIVTSQR_T6': 0.0,
#  'O3_DIVTSQR_T10': 0.0,
#  'CH4_DIVTSQR_T3': 0.0,
#  'CH4_DIVTSQR_T4': 0.0,
#  'CH4_DIVTSQR_T5': 0.0,
#  'CH4_DIVTSQR_T6': 0.0,
#  'CH4_DIVTSQR_T7': 0.0,
#  'CH4_DIVTSQR_T8': 0.0,
#  'CH4_DIVTSQR_T9': 0.0,
#  'CH4_DIVTSQR_T10': 0.0,
#  'CH4_DIVTSQR_T11': 0.0,
#  'CH4_DIVTSQR_T12': 0.0,
#  'CO_DIVTSQR_T3': 0.0,
#  'CO_DIVTSQR_T4': 0.0,
#  'CO_DIVTSQR_T6': 0.0,
#  'CO_DIVTSQR_T7': 0.0,
#  'CO_DIVTSQR_T8': 0.0,
#  'CO_DIVTSQR_T9': 0.0,
#  'CO_DIVTSQR_T10': 0.0,
#  'CO_DIVTSQR_T11': 0.0,
#  'NMHC_DIVTSQR_T2': 0.0,
#  'NMHC_DIVTSQR_T5': 0.0,
#  'NMHC_DIVTSQR_T6': 0.0,
#  'NMHC_DIVTSQR_T7': 0.0,
#  'NMHC_DIVTSQR_T8': 0.0,
#  'NMHC_DIVTSQR_T9': 0.0,
#  'NMHC_DIVTSQR_T10': 0.0,
#  'NMHC_DIVTSQR_T11': 0.0,
#  'NMHC_DIVTSQR_T12': 0.0,
#  'NO_DIVTSQR_T4': 0.0,
#  'NO_DIVTSQR_T5': 0.0,
#  'NO_DIVTSQR_T6': 0.0,
#  'NO_DIVTSQR_T7': 0.0,
#  'NO_DIVTSQR_T8': 0.0,
#  'NO_DIVTSQR_T11': 0.0,
#  'NO2_DIVTSQR_T2': 0.0,
#  'NO2_DIVTSQR_T3': 0.0,
#  'NO2_DIVTSQR_T4': 0.0,
#  'NO2_DIVTSQR_T5': 0.0,
#  'NO2_DIVTSQR_T6': 0.0,
#  'NO2_DIVTSQR_T8': 0.0,
#  'NO2_DIVTSQR_T9': 0.0,
#  'NO2_DIVTSQR_T10': 0.0,
#  'NO2_DIVTSQR_T11': 0.0,
#  'NO2_DIVTSQR_T12': 0.0,
#  'NOx_DIVTSQR_T2': 0.0,
#  'NOx_DIVTSQR_T3': 0.0,
#  'NOx_DIVTSQR_T4': 0.0,
#  'NOx_DIVTSQR_T5': 0.0,
#  'NOx_DIVTSQR_T6': 0.0,
#  'NOx_DIVTSQR_T7': 0.0,
#  'NOx_DIVTSQR_T9': 0.0,
#  'NOx_DIVTSQR_T10': 0.0,
#  'NOx_DIVTSQR_T11': 0.0,
#  'NOx_DIVTSQR_T12': 0.0,
#  'PM10_DIVTSQR_T5': 0.0,
#  'PM10_DIVTSQR_T6': 0.0,
#  'PM10_DIVTSQR_T10': 0.0,
#  'PM10_DIVTSQR_T11': 0.0,
#  'SO2_DIVTSQR_T2': 0.0,
#  'SO2_DIVTSQR_T3': 0.0,
#  'SO2_DIVTSQR_T4': 0.0,
#  'SO2_DIVTSQR_T6': 0.0,
#  'SO2_DIVTSQR_T7': 0.0,
#  'THC_DIVTSQR_T2': 0.0,
#  'THC_DIVTSQR_T3': 0.0,
#  'THC_DIVTSQR_T4': 0.0,
#  'THC_DIVTSQR_T5': 0.0,
#  'THC_DIVTSQR_T6': 0.0,
#  'THC_DIVTSQR_T7': 0.0,
#  'THC_DIVTSQR_T8': 0.0,
#  'THC_DIVTSQR_T9': 0.0,
#  'THC_DIVTSQR_T10': 0.0,
#  'THC_DIVTSQR_T11': 0.0,
#  'THC_DIVTSQR_T12': 0.0}

# %%
reg.predict(X_test[:10])
# Out:
# array([ 7.24844643,  7.53183092,  7.04162123,  8.85054302,  8.92311573,
#         9.93164425, 11.63985674, 11.68850291, 11.85911864, 11.13724998])

# %%
list(y_test[:10])
# Out:
# [8.0, 6.0, 18.0, 29.0, 28.0, 25.0, 20.0, 23.0, 21.0, 31.0]

# %%
abs(reg.predict(X_test[:10]) - y_test[:10])
# Out:
# 0     0.751554
# 1     1.531831
# 2    10.958379
# 3    20.149457
# 4    19.076884
# 5    15.068356
# 6     8.360143
# 7    11.311497
# 8     9.140881
# 9    19.862750
# Name: PM25_NOW, dtype: float64

# %%
sum(abs(reg.predict(X_test) - y_test))
# Out:
# 51674.144640427585

# %%
len(X_test)
# Out:
# 8676

# %%
print('Avg. MAE = ' + str(sum(abs(reg.predict(X_test) - y_test))/len(X_test)))
# Out:
# Avg. MAE = 5.955987164641262
